# %% [markdown]
# # Generating Account Features and Exploring Clustering Techniques

# %% [markdown]
# ## Step 1. Generating Account Features

# %% [markdown]
# Run a bigquery to get data between '2019-12-1' and '2019-12-31'
#
# where
#     - TransactionResult="tesSUCCESS"
#
# Get BigQuery Data into workable form as show below:
#
#
# |Account Hash|Sum of XRP Received| Sum of XRP Sent|Sum of Fees| Number of Txns|
# |-----|-------|------|------|-----|

# %% [markdown]
# Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn import preprocessing
#from scipy.stats import shapiro
from scipy.cluster.hierarchy import dendrogram, linkage 
from scipy.cluster.hierarchy import fcluster
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
import sys
from os import path

# %%
from ../../Utils/xrp_ml_utils.py import *
# Out:
#   File "<ipython-input-29-e56ad4161906>", line 1
#     from ../../Utils/xrp_ml_utils.py import *
#            ^
# SyntaxError: invalid syntax

# %%
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('../../Utils/xrp_ml_utils.py'),os.path.pardir)))

# %%
import xrp_ml_utils.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-026ba1da7c08> in <module>
# ----> 1 import xrp_ml_utils.py
#
# ImportError: No module named 'xrp_ml_utils'

# %% [markdown]
# Setting Window for Query

# %%
start_date='2019-12-1'
end_date='2019-12-31'

# %%
cred_path='../../credential/Xpring Dev Sandbox-edb2a98acf17.json'

# %%
def get_gcp_creds(key_path):
    """
    Return GCP credentials from local .json
    
    Parameters
    ----------
    key_path: str
        Path to local credential .json
    """
    try:
        credentials = service_account.Credentials.from_service_account_file(
            key_path,
            scopes = ["https://www.googleapis.com/auth/cloud-platform"]
        )
    except:
        credentials = None
    return credentials;

# %%
def gbq_query(query,cred, query_params=None):
    """
    Run a query against Google Big Query, returning a pandas dataframe of the result.

    Parameters
    ----------
    query: str
        The query string
    cred: obj
        Credential class instance
    
    query_params: list, optional
        The query parameters to pass into the query string
    """
    client = bigquery.Client(credentials=cred)
    job_config = bigquery.QueryJobConfig()
    job_config.query_parameters = query_params
    return client.query(query, job_config=job_config).to_dataframe()

# %%
#Query and query_parameters
query1 = """
Select 
  TIMESTAMP(l.CloseTime) as `TimeStamp`,
  t.Account,t.Destination,t.Fee,t.TxnSignature,t.AmountXRP,t.LedgerIndex,t.TransactionType
FROM
  `xrpledgerdata.fullhistory.transactions`t
JOIN
  `xrpledgerdata.fullhistory.ledgers` l
  on t.LedgerIndex=l.LedgerIndex
where t.TransactionResult = "tesSUCCESS"

AND TIMESTAMP(l.CloseTime) >=TIMESTAMP(@start_date)
AND TIMESTAMP(l.CloseTime) <=TIMESTAMP(@end_date)


ORDER BY TimeStamp

LIMIT 1000000

"""
query_params1 = [
    bigquery.ScalarQueryParameter("start_date", "STRING", start_date),
    bigquery.ScalarQueryParameter("end_date", "STRING", end_date)
]

# %%
xrp1=gbq_query(query1,get_gcp_creds(cred_path),query_params1)

# %%
xrp1
# Out:
#                        TimeStamp                             Account  \
# 0      2019-12-01 00:00:00+00:00  rDcPjwP7aAtLAPUWMJoEt3ZWS2xjqnEkW6
# 1      2019-12-01 00:00:00+00:00  rQNHoQJNBoRSN8U16ufcqrFDYwYCgqguQY
# 2      2019-12-01 00:00:00+00:00  rpnScMMLsTdFofHpLwTFrUAT5F4kSKggiq
# 3      2019-12-01 00:00:00+00:00  rDc2KgoWg2CQaHPUDmmpqF8Xd7xQzzrqbN
# 4      2019-12-01 00:00:00+00:00  r4GXbgT8eekMR5FEapdMaiJikyNTw7Pf45
# ...                          ...                                 ...
# 999995 2019-12-01 05:48:41+00:00  rh3VLyj1GbQjX7eA15BwUagEhSrPHmLkSR
# 999996 2019-12-01 05:48:41+00:00  rh3VLyj1GbQjX7eA15BwUagEhSrPHmLkSR
# 999997 2019-12-01 05:48:41+00:00  rBXqvQZw3DoioL1mP5A7ojVs48ZvYdMxqD
# 999998 2019-12-01 05:48:41+00:00  rh3VLyj1GbQjX7eA15BwUagEhSrPHmLkSR
# 999999 2019-12-01 05:48:41+00:00  rhhuf1w2bUj37zfd1uUciyxn9DQKMdrPH1
#
#                                Destination   Fee  \
# 0       rPGUevcGnMoF85sfZrtL1x6EXhM2wG4Fmx    12
# 1       rKBMcNV8xwVHvw9nNk3WCZtnnXuGiggaoe  7632
# 2       rKoyASc15cjD6sFQs4w9nvX3GRVXkAHt4t    12
# 3       rHo16GoWkEZar8zhEDfGxcRxMLo8qMqk1b    12
# 4       rB2UYkwenKDKxCFCXkx17fyqWw3ebYWqjE    12
# ...                                    ...   ...
# 999995                                None    12
# 999996                                None    12
# 999997  rstaazHNsnJWtwA2xFxjBWWFip67c9Ky5P    12
# 999998                                None    12
# 999999  rfqrKvXLAPYhpZU4oWxmc5Z3syL2py74zN    12
#
#                                              TxnSignature  AmountXRP  \
# 0       3045022100C302E68D787E67F918E952228482AFA436AC...        NaN
# 1       304402207D60892A0B15AFB756959B5E3D49B612506FAF...        NaN
# 2       3044022024EBE8941EBE1C183EB258D82639BFEC396C84...        NaN
# 3       30440220025712E85B2F22C95F14D0EBA4DC031BDB3D74...        NaN
# 4       3045022100E1F584F79C539C17B24C63A2D6C487B92713...        NaN
# ...                                                   ...        ...
# 999995  304402200CABD23D64CBC418C63C3744B1DDA517002CB1...        NaN
# 999996  3045022100E7F6C9F34135FED935263ED4AF5C1BFA17C8...        NaN
# 999997  3045022100E2396F9F0F85534535DA7BC318444B95F194...        NaN
# 999998  3045022100ECD748A2B260CACC2FF2BF1A3927073AF7AF...        NaN
# 999999  3044022047A1558C6FF82DF00D4935EE3CB8C37A9C5057...        NaN
#
#         LedgerIndex TransactionType
# 0          51752122         Payment
# 1          51752122         Payment
# 2          51752122         Payment
# 3          51752122         Payment
# 4          51752122         Payment
# ...             ...             ...
# 999995     51757334     OfferCreate
# 999996     51757334     OfferCreate
# 999997     51757334         Payment
# 999998     51757334     OfferCreate
# 999999     51757334         Payment
#
# [1000000 rows x 8 columns]

# %%
xrp1.isnull().sum()
# Out:
# TimeStamp               0
# Account                 0
# Destination        295596
# Fee                     0
# TxnSignature          367
# AmountXRP          991520
# LedgerIndex             0
# TransactionType         0
# dtype: int64

# %%
xrp1['TransactionType'].value_counts()
# Out:
# Payment         704404
# OfferCreate     288214
# OfferCancel       7220
# AccountSet         152
# TrustSet             7
# EscrowFinish         3
# Name: TransactionType, dtype: int64

# %%
#Query and query_parameters
query2 = """
Select 
  TIMESTAMP(l.CloseTime) as `TimeStamp`,
  t.Account,t.Destination,t.Fee,t.TxnSignature,t.AmountXRP,t.LedgerIndex,t.TransactionType
FROM
  `xrpledgerdata.fullhistory.transactions`t
JOIN
  `xrpledgerdata.fullhistory.ledgers` l
  on t.LedgerIndex=l.LedgerIndex
where t.TransactionResult = "tesSUCCESS"
AND TxnSignature IS NOT NULL
AND Destination IS NOT NULL
AND AmountXRP  IS NOT NULL
AND TIMESTAMP(l.CloseTime) >=TIMESTAMP(@start_date)
AND TIMESTAMP(l.CloseTime) <=TIMESTAMP(@end_date)


ORDER BY TimeStamp

LIMIT 1000000

"""
query_params2 = [
    bigquery.ScalarQueryParameter("start_date", "STRING", start_date),
    bigquery.ScalarQueryParameter("end_date", "STRING", end_date)
]

# %%
path='../../Data/'

# %%
xrp2=gbq_query(query2,get_gcp_creds(cred_path),query_params2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-68d531261132> in <module>
# ----> 1 xrp2=gbq_query(query2,get_gcp_creds(cred_path),query_params2)
#       2 xrp2.to_csv(os.path.join(path,r'12_1_2019_to_12_30_2019_DownselectALL.csv'))
#
# <ipython-input-71-6da610cb9a50> in gbq_query(query, cred, query_params)
#      16     job_config = bigquery.QueryJobConfig()
#      17     job_config.query_parameters = query_params
# ---> 18     return client.query(query, job_config=job_config).to_dataframe()
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type)
#    3247             ValueError: If the `pandas` library cannot be imported.
#    3248         """
# -> 3249         return self.result().to_dataframe(
#    3250             bqstorage_client=bqstorage_client,
#    3251             dtypes=dtypes,
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry, max_results)
#    3122         """
#    3123         try:
# -> 3124             super(QueryJob, self).result(timeout=timeout)
#    3125
#    3126             # Return an iterator instead of returning the job.
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     777             self._begin(retry=retry)
#     778         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 779         return super(_AsyncJob, self).result(timeout=timeout)
#     780
#     781     def cancelled(self):
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    3035     def _blocking_poll(self, timeout=None):
#    3036         self._done_timeout = timeout
# -> 3037         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    3038
#    3039     @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     275                 sleep_generator,
#     276                 self._deadline,
# --> 277                 on_error=on_error,
#     278             )
#     279
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     180     for sleep in sleep_generator:
#     181         try:
# --> 182             return target()
#     183
#     184         # pylint: disable=broad-except
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/job.py in done(self, retry)
#    3022                 project=self.project,
#    3023                 timeout_ms=timeout_ms,
# -> 3024                 location=self.location,
#    3025             )
#    3026
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location)
#    1110         # QueryJob.result()). So we don't need to poll here.
#    1111         resource = self._call_api(
# -> 1112             retry, method="GET", path=path, query_params=extra_params
#    1113         )
#    1114         return _QueryResults.from_api_repr(resource)
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     485         if retry:
#     486             call = retry(call)
# --> 487         return call()
#     488
#     489     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     275                 sleep_generator,
#     276                 self._deadline,
# --> 277                 on_error=on_error,
#     278             )
#     279
#
# /usr/local/lib/python3.5/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     180     for sleep in sleep_generator:
#     181         try:
# --> 182             return target()
#     183
#     184         # pylint: disable=broad-except
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     415             headers=headers,
#     416             target_object=_target_object,
# --> 417             timeout=timeout,
#     418         )
#     419
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/_http.py in _make_request(self, method, url, data, content_type, headers, target_object, timeout)
#     273
#     274         return self._do_request(
# --> 275             method, url, headers, data, target_object, timeout=timeout
#     276         )
#     277
#
# /usr/local/lib/python3.5/dist-packages/google/cloud/_http.py in _do_request(self, method, url, headers, data, target_object, timeout)
#     311         """
#     312         return self.http.request(
# --> 313             url=url, method=method, headers=headers, data=data, timeout=timeout
#     314         )
#     315
#
# /usr/local/lib/python3.5/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, **kwargs)
#     214
#     215         response = super(AuthorizedSession, self).request(
# --> 216             method, url, data=data, headers=request_headers, **kwargs
#     217         )
#     218
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.5/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# /usr/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
xrp2
# Out:
#                        TimeStamp                             Account  \
# 0      2019-12-01 00:00:01+00:00  rfQLYTZk7iBSekEv1GughC1ruWfCDeZXVz
# 1      2019-12-01 00:00:01+00:00   rAPERVgXZavGgiGv6xBgtiZurirW2yAmY
# 2      2019-12-01 00:00:02+00:00  rw2ciyaNshpHe7bCHo4bRWq6pqqynnWKQg
# 3      2019-12-01 00:00:10+00:00   rAPERVgXZavGgiGv6xBgtiZurirW2yAmY
# 4      2019-12-01 00:00:11+00:00   rAPERVgXZavGgiGv6xBgtiZurirW2yAmY
# ...                          ...                                 ...
# 707188 2019-12-30 23:59:42+00:00  rDsbeomae4FXwgQTJp9Rs64Qg9vDiTCdBv
# 707189 2019-12-30 23:59:42+00:00  rDsbeomae4FXwgQTJp9Rs64Qg9vDiTCdBv
# 707190 2019-12-30 23:59:50+00:00  rDsbeomae4FXwgQTJp9Rs64Qg9vDiTCdBv
# 707191 2019-12-30 23:59:50+00:00  rDsbeomae4FXwgQTJp9Rs64Qg9vDiTCdBv
# 707192 2019-12-30 23:59:51+00:00  rwU8rAiE2eyEPz3sikfbHuqCuiAtdXqa2v
#
#                                Destination    Fee  \
# 0       rP1afBEfikTz7hJh2ExCDni9W4Bx1dUMRk  16305
# 1       rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA  12645
# 2       rLNaPoKeeBjZe2qs6x52yVPZpZ8td4dc6w     40
# 3       rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA     12
# 4       rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA     12
# ...                                    ...    ...
# 707188  rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA  60000
# 707189  rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA  60000
# 707190  rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA  60000
# 707191  rU2mEJSLqBRkYLVTv55rFTgQajkLTnT6mA  60000
# 707192  rK7LSKygRUu9y9xcuhkWbcMRKRF5HVWwVL     20
#
#                                              TxnSignature   AmountXRP  \
# 0       30450221009B3E7024448E56F1E580F4AFCBBC9BECF050...   222000000
# 1       3045022100C1839ADD174EF85C785E452A83CF0AD655BF...          32
# 2       3045022100BE2F8FBCC8A76A31CDA4FF0A13BA2120EB71...   360980050
# 3       3045022100D41EF19727BECD8B77976FC731F86A6F4CD1...          30
# 4       3045022100B38D74883970A9A21497A520BA4A56C28EF0...          30
# ...                                                   ...         ...
# 707188  304402204918F22DEB8B151FA28FA64AA994B1392B3320...   325686594
# 707189  304502210087CC7A6B27090ED095E8BA8F479EF628695C...   275267296
# 707190  304402200A23218923346C7E5C868B6941700630A6FBF6...  5083632552
# 707191  3044022075F91DAF97CC80563D673B9DFB742DCF73F782...   732509247
# 707192  3045022100FF9DB9AF4B9C66EBBE0F30E7F108D2B3AE5F...    40469535
#
#         LedgerIndex TransactionType
# 0          51752123         Payment
# 1          51752123         Payment
# 2          51752124         Payment
# 3          51752125         Payment
# 4          51752126         Payment
# ...             ...             ...
# 707188     52409894         Payment
# 707189     52409894         Payment
# 707190     52409895         Payment
# 707191     52409895         Payment
# 707192     52409896         Payment
#
# [707193 rows x 8 columns]

# %%
xrp2.to_csv(os.path.join(path,r'12_1_2019_to_12_30_2019_DownselectALL.csv'))

# %%
def dict_accounthash(data):
    #Creating a merged a numpy array of unique account and destination hashes
    UniqueAccount=np.unique(data['Account'])
    UniqueDestination=np.unique(data['Destination'])
    UniqueHash=np.unique(np.concatenate([UniqueDestination, UniqueAccount]))
    #Creating a dictionary with account hashes as keys and account balances initialized at 0 as the values
    #The value is an array of length 3 for summing xrp received, xrp sent, and sum of fees
    UniqueHashList=UniqueHash.tolist()
    listofzeros = [[0] *3 ]*len(UniqueHashList)
    dicAccBal = {k:v for k,v in zip(UniqueHashList,listofzeros)}
    

        #iterate through each transaction
    for index, row in xrp.iterrows():
        #Checking if the transaction's timestamp is within time window specified by starttime and endtime
        if (row['TimeStamp'] < endtime) & (row['TimeStamp'] > starttime):
        #Adding account balances to respective dictionary balance
            dicAccBal[row['Account']][i] += (-1) * (row['AmountXRP'])
            dicAccBal[row['Destination']][i] += (1) * (row['AmountXRP'])
    
    
    return dicAccBal
